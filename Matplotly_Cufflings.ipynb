# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df =pd.DataFrame(np.random.randn(1000), columns= ["data"],index=pd.date_range("26.03.2022",periods= 1000))

# %%
df
# Out:
#                 data
# 2022-03-26 -0.656290
# 2022-03-27 -0.383168
# 2022-03-28  0.916728
# 2022-03-29  0.117313
# 2022-03-30 -0.523448
# ...              ...
# 2024-12-15 -0.002543
# 2024-12-16  0.726167
# 2024-12-17  1.868834
# 2024-12-18 -0.078842
# 2024-12-19 -0.836559
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize =(30,10))
# Out:
# <AxesSubplot:>

# %%
df1=pd.read_csv("https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv")

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot(figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df1.tail().plot(kind ="bar", figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df1.iloc[[5]].plot(kind ="bar", figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df1.iloc[5:15]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# 13           4.3          3.0           1.1          0.1  setosa
# 14           5.8          4.0           1.2          0.2  setosa

# %%
df1.iloc[5:15].plot(kind ="barh", figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df1.iloc[5:15].plot(kind ="area", figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df1.plot(kind ="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1["sepal_length"].plot(kind = "hist", figsize =(20,10),orientation="horizontal")
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
df1["sepal_length"]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
df1.hist(figsize=(20,10), color = "r", alpha = 0.5)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot(kind = "box", figsize =(20,10), color ={"boxes" :"g","whiskers":"r"})
# Out:
# <AxesSubplot:>

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df1.plot(kind ="area" ,figsize =(20,10),stacked =True)
# Out:
# <AxesSubplot:>

# %%
df1.plot.scatter(x ="sepal_length" , y ="petal_length" , c = "sepal_width" , s = df1["petal_width"]*300)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df1.plot.hexbin(x ="sepal_length" , y ="petal_length" , gridsize= 10 , C= "sepal_width")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df1.plot.scatter(x ="sepal_length" , y ="petal_width" )
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
df2=df1.drop(columns="species").iloc[[1]]

# %%
df2.plot(kind ="pie")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\VIVOBO~1\AppData\Local\Temp/ipykernel_34228/3091786273.py in <module>
# ----> 1 df2.plot(kind ="pie")
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     921             if isinstance(data, ABCDataFrame):
#     922                 if y is None and kwargs.get("subplots") is False:
# --> 923                     raise ValueError(
#     924                         f"{kind} requires either y column or 'subplots=True'"
#     925                     )
#
# ValueError: pie requires either y column or 'subplots=True'

# %%
df2
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 1           4.9          3.0           1.4          0.2

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import cufflinks as cf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\VIVOBO~1\AppData\Local\Temp/ipykernel_25260/189640202.py in <module>
# ----> 1 import cufflinks as cf
#
# ModuleNotFoundError: No module named 'cufflinks'

# %%
# !pip install cufflinks
# Out:
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68734 sha256=2ecd06e20c9398da7f11fea4d00554fed757b9c3529a27a765eaa76f90fa086e
#   Stored in directory: c:\users\vivobook-15\appdata\local\pip\cache\wheels\29\b4\f8\2fd2206eeeba6ccad8167e4e8894b8c4ec27bf1342037fd136
# Successfully built cufflinks
# ...

# %%
# !pip install plotly
# !pip install chart_studio
# Out:
# ...
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11448 sha256=e4c3dc05f350fe4947894331ac77750d630f32c5a7cbe4a46b64aae8ec95c502
#   Stored in directory: c:\users\vivobook-15\appdata\local\pip\cache\wheels\ce\18\7f\e9527e3e66db1456194ac7f61eb3211068c409edceecff2d31
# Successfully built retrying
# ...

# %%
import cufflinks as cf
cf.go_offline()

# %%
df1.iplot()
